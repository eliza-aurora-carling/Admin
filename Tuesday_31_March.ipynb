# %% [markdown]
# <a href="https://colab.research.google.com/github/eliza-aurora-carling/Admin/blob/main/Tuesday_31_March.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 'Raise' keyword
# Independent activity: try-except block to handle cases where user enters non-numeric values or negative numbers.
# If invalid input, show descriptive error message.
